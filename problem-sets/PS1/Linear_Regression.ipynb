# %%
import matplotlib.pyplot as plt

from src.linear_model import LinearModel
import src.util as util

# %%
linear_train_path = 'data/ds4_train.csv'
linear_valid_path = 'data/ds4_valid.csv'

# %%
linear_x_train, linear_y_train = util.load_dataset(linear_train_path)
linear_x_valid, linear_y_valid = util.load_dataset(linear_valid_path)

# %%
linear_model = LinearModel()
linear_model.fit(linear_x_train, linear_y_train)

# %%
util.plot(linear_x_train, linear_y_train, theta= linear_model.theta)
